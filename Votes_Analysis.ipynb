# %% [markdown]
# <a href="https://colab.research.google.com/github/debjena/Cognifyz_internship/blob/main/Votes_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LEVEL-3    Task-2**

# %%
# 📦 Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# ✅ Load dataset (Upload "Dataset .csv" manually if not already loaded)
df = pd.read_csv("Dataset .csv")

# ✅ Clean and prepare votes and rating columns
df['Votes'] = pd.to_numeric(df['Votes'], errors='coerce')
df['Aggregate rating'] = pd.to_numeric(df['Aggregate rating'], errors='coerce')

# Filter out rows with missing or 0 votes
df_votes = df.dropna(subset=['Votes', 'Aggregate rating'])
df_votes = df_votes[df_votes['Votes'] > 0]

# ✅ Step 1: Highest and Lowest Voted Restaurants

max_votes = df_votes['Votes'].max()
min_votes = df_votes['Votes'].min()

highest_voted = df_votes[df_votes['Votes'] == max_votes][['Restaurant Name', 'Votes', 'Aggregate rating']]
lowest_voted = df_votes[df_votes['Votes'] == min_votes][['Restaurant Name', 'Votes', 'Aggregate rating']]

print("🏆 Highest Voted Restaurant(s):")
display(highest_voted)

print("\n🧾 Lowest Voted Restaurant(s):")
display(lowest_voted)

# ✅ Step 2: Correlation between Votes and Rating

correlation = df_votes[['Votes', 'Aggregate rating']].corr().iloc[0, 1]
print(f"\n📈 Correlation between votes and rating: {round(correlation, 3)}")

# ✅ Step 3: Visualization - Scatter Plot

plt.figure(figsize=(8, 5))
plt.scatter(df_votes['Votes'], df_votes['Aggregate rating'], alpha=0.5, color='teal')
plt.title('Votes vs Aggregate Rating')
plt.xlabel('Number of Votes')
plt.ylabel('Aggregate Rating')
plt.grid(True)
plt.show()
# Out:
# 🏆 Highest Voted Restaurant(s):
#     Restaurant Name    Votes  Aggregate rating
# 728            Toit  10934.0               4.8
# 🧾 Lowest Voted Restaurant(s):
#              Restaurant Name  Votes  Aggregate rating
# 58     Quiosque Chopp Brahma    1.0               0.0
# 412               Nosh Mahal    1.0               0.0
# 871    Aggarwal Sweet Corner    1.0               0.0
# 878              Aapki Rasoi    1.0               0.0
# 888           Popcorn Fusion    1.0               0.0
# ...                      ...    ...               ...
# 4312        Chill House Kafe    1.0               0.0
# 4362  Amul Ice-Cream Parlour    1.0               0.0
# 4377  Al-Malik Chicken Point    1.0               0.0
# 4380                 Food 24    1.0               0.0
# 4384           Hide Out Cafe    1.0               0.0
#
# [153 rows x 3 columns]
# 📈 Correlation between votes and rating: 0.303
